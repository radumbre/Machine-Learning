# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OrdinalEncoder
from sklearn.linear_model import LinearRegression, Lasso,  Ridge, ElasticNet
from sklearn.metrics import r2_score
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv("https://raw.githubusercontent.com/aishwaryamate/Datasets/main/cars.csv")

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# 0            rwd           front   64.1    48.8        dohc          130
# 1            rwd           front   64.1    48.8        dohc          130
# 2            rwd           front   65.5    52.4        ohcv          152
# 3            fwd           front   66.2    54.3         ohc          109
# 4            4wd           front   66.4    54.3         ohc          136
# ..           ...             ...    ...     ...         ...          ...
# 200          rwd           front   68.9    55.5         ohc          141
# 201          rwd           front   68.8    55.5         ohc          141
# 202          rwd           front   68.9    55.5        ohcv          173
# 203          rwd           front   68.9    55.5         ohc          145
# 204          rwd           front   68.9    55.5         ohc          141
#
#     horsepower  city-mpg  highway-mpg  price
# 0          111        21           27  13495
# 1          111        21           27  16500
# 2          154        19           26  16500
# 3          102        24           30  13950
# 4          115        18           22  17450
# ..         ...       ...          ...    ...
# 200        114        23           28  16845
# 201        160        19           25  19045
# 202        134        18           23  21485
# 203        106        26           27  22470
# 204        114        19           25  22625
#
# [205 rows x 15 columns]

# %%
df.replace("?", np.nan,inplace=True)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3               NaN  alfa-romero       gas  convertible
# 1            3               NaN  alfa-romero       gas  convertible
# 2            1               NaN  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# 0            rwd           front   64.1    48.8        dohc          130
# 1            rwd           front   64.1    48.8        dohc          130
# 2            rwd           front   65.5    52.4        ohcv          152
# 3            fwd           front   66.2    54.3         ohc          109
# 4            4wd           front   66.4    54.3         ohc          136
# ..           ...             ...    ...     ...         ...          ...
# 200          rwd           front   68.9    55.5         ohc          141
# 201          rwd           front   68.8    55.5         ohc          141
# 202          rwd           front   68.9    55.5        ohcv          173
# 203          rwd           front   68.9    55.5         ohc          145
# 204          rwd           front   68.9    55.5         ohc          141
#
#     horsepower  city-mpg  highway-mpg  price
# 0          111        21           27  13495
# 1          111        21           27  16500
# 2          154        19           26  16500
# 3          102        24           30  13950
# 4          115        18           22  17450
# ..         ...       ...          ...    ...
# 200        114        23           28  16845
# 201        160        19           25  19045
# 202        134        18           23  21485
# 203        106        26           27  22470
# 204        114        19           25  22625
#
# [205 rows x 15 columns]

# %%
si = SimpleImputer()

df.iloc[:,[1,11]] = si.fit_transform(df.iloc[:,[1,11]])
df
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3              122.0  alfa-romero       gas  convertible
# 1            3              122.0  alfa-romero       gas  convertible
# 2            1              122.0  alfa-romero       gas    hatchback
# 3            2              164.0         audi       gas        sedan
# 4            2              164.0         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 200         -1               95.0        volvo       gas        sedan
# 201         -1               95.0        volvo       gas        sedan
# 202         -1               95.0        volvo       gas        sedan
# 203         -1               95.0        volvo    diesel        sedan
# 204         -1               95.0        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# 0            rwd           front   64.1    48.8        dohc          130
# 1            rwd           front   64.1    48.8        dohc          130
# 2            rwd           front   65.5    52.4        ohcv          152
# 3            fwd           front   66.2    54.3         ohc          109
# 4            4wd           front   66.4    54.3         ohc          136
# ..           ...             ...    ...     ...         ...          ...
# 200          rwd           front   68.9    55.5         ohc          141
# 201          rwd           front   68.8    55.5         ohc          141
# 202          rwd           front   68.9    55.5        ohcv          173
# 203          rwd           front   68.9    55.5         ohc          145
# 204          rwd           front   68.9    55.5         ohc          141
#
#      horsepower  city-mpg  highway-mpg  price
# 0         111.0        21           27  13495
# 1         111.0        21           27  16500
# 2         154.0        19           26  16500
# 3         102.0        24           30  13950
# 4         115.0        18           22  17450
# ..          ...       ...          ...    ...
# 200       114.0        23           28  16845
# 201       160.0        19           25  19045
# 202       134.0        18           23  21485
# 203       106.0        26           27  22470
# 204       114.0        19           25  22625
#
# [205 rows x 15 columns]

# %%
cat_cols = df.select_dtypes(object).columns
cat_cols
# Out:
# Index(['make', 'fuel-type', 'body-style', 'drive-wheels', 'engine-location',
#        'engine-type'],
#       dtype='object')

# %%
oe = OrdinalEncoder()

df[cat_cols] = oe.fit_transform(df[cat_cols])
df
# Out:
#      symboling  normalized-losses  make  fuel-type  body-style  drive-wheels  \
# 0            3              122.0   0.0        1.0         0.0           2.0
# 1            3              122.0   0.0        1.0         0.0           2.0
# 2            1              122.0   0.0        1.0         2.0           2.0
# 3            2              164.0   1.0        1.0         3.0           1.0
# 4            2              164.0   1.0        1.0         3.0           0.0
# ..         ...                ...   ...        ...         ...           ...
# 200         -1               95.0  21.0        1.0         3.0           2.0
# 201         -1               95.0  21.0        1.0         3.0           2.0
# 202         -1               95.0  21.0        1.0         3.0           2.0
# 203         -1               95.0  21.0        0.0         3.0           2.0
# 204         -1               95.0  21.0        1.0         3.0           2.0
#
#      engine-location  width  height  engine-type  engine-size  horsepower  \
# 0                0.0   64.1    48.8          0.0          130       111.0
# 1                0.0   64.1    48.8          0.0          130       111.0
# 2                0.0   65.5    52.4          5.0          152       154.0
# 3                0.0   66.2    54.3          3.0          109       102.0
# 4                0.0   66.4    54.3          3.0          136       115.0
# ..               ...    ...     ...          ...          ...         ...
# 200              0.0   68.9    55.5          3.0          141       114.0
# 201              0.0   68.8    55.5          3.0          141       160.0
# 202              0.0   68.9    55.5          5.0          173       134.0
# 203              0.0   68.9    55.5          3.0          145       106.0
# 204              0.0   68.9    55.5          3.0          141       114.0
#
#      city-mpg  highway-mpg  price
# 0          21           27  13495
# 1          21           27  16500
# 2          19           26  16500
# 3          24           30  13950
# 4          18           22  17450
# ..        ...          ...    ...
# 200        23           28  16845
# 201        19           25  19045
# 202        18           23  21485
# 203        26           27  22470
# 204        19           25  22625
#
# [205 rows x 15 columns]

# %%
x = df.iloc[:,:-1]
y = df['price']

# %%
from sklearn.model_selection import train_test_splitin_test_split

# %%
xtrain,xtest,ytrain,ytest= train_test_split(x,y,test_size =0.3, random_state=1 )

# %%
lr = LinearRegression()
lr.fit(xtrain,ytrain)
ypred = lr.predict(xtest)

print(f"Train Accuracy is {lr.score(xtrain,ytrain) }\nTest Accuracy is {lr.score(xtest,ytest)}")
# Out:
# Train Accuracy is 0.8504573774895472
# Test Accuracy is 0.7965566780397382

# %%
lr.coef_
# Out:
# array([ 4.51384957e+01,  1.53127607e+00, -2.00099087e+02, -6.22650015e+02,
#        -1.70235175e+02,  1.86860719e+03,  1.64133620e+04,  7.89452171e+02,
#         3.62663990e+02,  2.83174279e+02,  9.83682875e+01, -1.08169245e+01,
#         3.08017854e+02, -4.17024371e+02])

# %% [markdown]
# # Lasso

# %%
l1 = Lasso(alpha =1)
l1.fit(xtrain,ytrain)
print(f"Train Accuracy is {l1.score(xtrain,ytrain) }\nTest Accuracy is {l1.score(xtest,ytest)}")
# Out:
# Train Accuracy is 0.8504560242712866
# Test Accuracy is 0.7967303673537032

# %%
l1.coef_
# Out:
# array([ 4.49259347e+01,  1.53240659e+00, -1.99923068e+02, -6.14190997e+02,
#        -1.71341059e+02,  1.86538556e+03,  1.63433231e+04,  7.87471142e+02,
#         3.63257326e+02,  2.83240951e+02,  9.84589905e+01, -1.06994004e+01,
#         3.06876373e+02, -4.15639005e+02])

# %% [markdown]
# # Hperparameter Tuning

# %%
for i in range(100,200):
    l1=Lasso(alpha = i)
    l1.fit(xtrain,ytrain)
    
    print(f"{i} {l1.score(xtrain,ytrain)}{l1.score(xtest,ytest)}")
# Out:
# 100 0.83729228691014720.8089989519118683
# 101 0.83703400196540770.8090893744316343
# 102 0.83677314934178120.8091789601051912
# 103 0.83650972882337350.8092677091597652
# 104 0.8362437397599860.809355622090732
# 105 0.83597518207640180.809442698991254
# 106 0.83570396061284020.8095289994157535
# 107 0.8354302648464560.8096144037402809
# 108 0.83515399965583490.8096989726368534
# 109 0.83487516517688110.8097827060334882
# 110 0.83459365980749870.8098656626873878
# 111 0.8343096863633720.8099477241988432
# 112 0.83402314356657330.8100289502941956
# 113 0.83373403138476190.8101093409999014
# 114 0.8334422416130590.8101889541347452
# 115 0.83314799034452250.8102676731159629
# 116 0.83285116958934210.8103455567944016
# 117 0.83255177929781950.8104226051983998
# 118 0.83224970464731620.8104988749770783
# 119 0.83194517526712760.8105742517223582
# 120 0.83163807657587110.8106487931098093
# 121 0.83132840802851950.8107224994000667
# 122 0.83101604858136880.8107954256724004
# 123 0.83070124159400340.8108674600699219
# 124 0.83038386543337340.8109386590895038
# 125 0.83006379104151920.8110090779783015
# 126 0.82974127781459630.8110786046101633
# 127 0.82941619327879850.811147296809698
# 128 0.82908854159882440.8112151528557928
# 129 0.82875818272245290.8112822279697266
# 130 0.82842539218390430.8113484125018898
# 131 0.82809003223224590.8114137618538081
# 132 0.82775195941647350.8114783290463339
# 133 0.82741145951655160.8115420073263577
# 134 0.82706839141918240.8116048499989015
# 135 0.82672260558317990.8116669088959726
# 136 0.82637439896572780.8117280800422857
# 137 0.82602361953108880.8117884171818313
# 138 0.82567011862551240.8118479684391815
# 139 0.82531420412576410.8119066329309855
# 140 0.82495572022304550.8119644623062722
# 141 0.82459450471396180.8120215057130256
# 142 0.82423088256033060.8120776635797977
# 143 0.82386469646800590.8121329847719011
# 144 0.82349576265890150.8121875213446352
# 145 0.82312443142953680.8122411730693034
# 146 0.82275053080758830.8122939897000173
# 147 0.82237388445541940.8123460176376023
# 148 0.82199484762294250.8123971623068158
# 149 0.82161305989194310.8124475174022219
# 150 0.82122888798563460.8124969899539802
# 151 0.82084214682380590.8125456274822552
# 152 0.82045265184237890.8125934728624999
# 153 0.82006077621576380.8126404383406128
# 154 0.81966613043883570.812686613158391
# 155 0.81926911487735220.8127319078642978
# 156 0.81886953013697260.8127763675886548
# 157 0.81846717152237080.8128200339758357
# 158 0.8180624498620350.8128628223230777
# 159 0.81765494645010840.8129048166168777
# 160 0.81724508810509140.8129459336049878
# 161 0.81683244001541920.8129862557319262
# 162 0.81641744524577850.8130257013815374
# 163 0.81599988207858230.8130643120104756
# 164 0.81557952851501030.8131021244780069
# 165 0.81515683030424970.8131390636923393
# 166 0.81473132712939230.8131752048184053
# 167 0.81430349148353540.8132104730535141
# 168 0.81387284459875740.8132449418027805
# 169 0.81343987346969360.8132785388258218
# 170 0.81300408325738730.8133113351310719
# 171 0.81256597719589640.8133432609587987
# 172 0.81212504425170130.8133743847411005
# 173 0.81168180345367120.8134046394507298
# 174 0.81123572818417430.8134340906730739
# 175 0.8107870764307890.8134627056104382
# 176 0.81033613622124960.8134904529225561
# 177 0.80988234317033390.8135173951756092
# 178 0.80942626978495090.8135434714951191
# 179 0.80896733645462790.8135687410139806
# 180 0.80850613666096650.8135931458580312
# 181 0.80804207408968410.8136167417778959
# 182 0.80757543517752560.8136395013563877
# 183 0.80710654327476480.8136613991108353
# 184 0.8066347716240650.8136824856857403
# 185 0.80616043180145320.813702735329729
# 186 0.80568386643105570.813722125440687
# 187 0.80520410156627590.8137408849674855
# 188 0.80472229733452370.8137596939863233
# 189 0.8042382880047520.8137776284463011
# 190 0.80375135213849440.8137947641762748
# 191 0.80326184502551660.813811063097278
# 192 0.8027697671354810.8138265251565118
# 193 0.80227551501128440.8138411159732442
# 194 0.80177831490558590.8138549042746758
# 195 0.80127855308805210.8138678551231548
# 196 0.80077622457559430.8138799689918146
# 197 0.80027133031852950.8138912458531994
# 198 0.79976387137318470.8139016856863965
# 199 0.79925428908275420.8139112605131598

# %%
l1 = Lasso(alpha = 170)
l1.fit(xtrain,ytrain)
print(f"Train Accuracy is {l1.score(xtrain,ytrain)}\nTest Accuracy is {l1.score(xtest,ytest)})")
# Out:
# Train Accuracy is 0.8130040832573873
# Test Accuracy is 0.8133113351310719)

# %%
l1.coef_
# Out:
# array([ 4.43490130e+00,  2.00056602e+00, -1.72066327e+02, -0.00000000e+00,
#        -3.70073745e+02,  1.23453446e+03,  4.27843994e+03,  3.99653319e+02,
#         4.53832760e+02,  3.01208227e+02,  1.13098477e+02,  1.02575283e+01,
#         8.04028285e+01, -1.69892755e+02])

# %% [markdown]
# # Ridge

# %%
l2 = Ridge()
l2.fit(xtrain,ytrain)

print(f"Train Accuracy is {l2.score(xtrain,ytrain)}\nTest Accuracy is {l2.score(xtest,ytest)})")
# Out:
# Train Accuracy is 0.8436019887231634
# Test Accuracy is 0.8074518758147271)

# %%
for i in range (1,50):
    l2 = Ridge(alpha=i)
    l2.fit(xtrain,ytrain)
    print(f"{i} {l2.score(xtrain,ytrain)} {l2.score(xtest,ytest)}")
# Out:
# 1 0.8436019887231634 0.8074518758147271
# 2 0.8356568294333326 0.8110292248150515
# 3 0.829596685378384 0.8126933383890032
# 4 0.8250050456621351 0.8136148645029299
# 5 0.8214255248858179 0.8141745853539419
# 6 0.8185497905642731 0.8145301242133357
# 7 0.8161775446879697 0.8147582608502812
# 8 0.8141763553347593 0.8149010602831953
# 9 0.8124561449821562 0.8149836949253052
# 10 0.8109538582620315 0.8150222867376525
# 11 0.8096241695970483 0.8150277245431792
# 12 0.8084337140523127 0.8150076788279419
# 13 0.8073574061115951 0.8149677381788261
# 14 0.8063760269401786 0.8149120868051176
# 15 0.8054746030665225 0.8148439278252516
# 16 0.8046412917341841 0.814765758494739
# 17 0.8038665985400391 0.8146795554128126
# 18 0.8031428178838972 0.8145869029046835
# 19 0.8024636258876571 0.8144890843369585
# 20 0.8018237796035674 0.814387148544555
# 21 0.8012188915864451 0.8142819591129825
# 22 0.8006452587395116 0.8141742315788493
# 23 0.8000997308073307 0.8140645619421538
# 24 0.7995796082141258 0.8139534488166058
# 25 0.7990825618875559 0.8138413108452037
# 26 0.7986065697399166 0.8137285005403767
# 27 0.7981498659021868 0.8136153153884843
# 28 0.797710899816778 0.8135020068362638
# 29 0.7972883030209654 0.8133887876197212
# 30 0.7968808619807589 0.8132758377831448
# 31 0.7964874957227426 0.813163309653795
# 32 0.7961072372991723 0.8130513319772292
# 33 0.7957392183371693 0.8129400133729976
# 34 0.7953826560857554 0.8128294452363016
# 35 0.7950368424986247 0.8127197041851855
# 36 0.7947011349858958 0.8126108541327798
# 37 0.7943749485418696 0.8125029480485759
# 38 0.7940577490133229 0.8123960294605082
# 39 0.7937490473179629 0.8122901337400303
# 40 0.7934483944582852 0.8121852892047277
# 41 0.7931553772043529 0.8120815180669058
# 42 0.7928696143416056 0.8119788372516914
# 43 0.792590753397955 0.8118772591041922
# 44 0.792318467779072 0.8117767920020494
# 45 0.7920524542526478 0.8116774408870528
# 46 0.7917924307321205 0.8115792077273271
# 47 0.791538134318277 0.8114820919198037
# 48 0.7912893195636812 0.8113860906412016
# 49 0.7910457569302703 0.8112911991545092

# %%
l2 = Ridge(alpha=10)
l2.fit(xtrain,ytrain)

print(f"Train Accuracy is {l2.score(xtrain,ytrain) }\nTest Accuracy is {l2.score(xtest,ytest)}")
# Out:
# Train Accuracy is 0.8109538582620315
# Test Accuracy is 0.8150222867376525

# %% [markdown]
# # Elastic Net

# %%
en = ElasticNet()
en.fit(xtrain,ytrain)

print(f"Train Accuracy is {en.score(xtrain,ytrain) }\nTest Accuracy is {en.score(xtest,ytest)}")
# Out:
# Train Accuracy is 0.7865776086026621
# Test Accuracy is 0.8094188583631502
